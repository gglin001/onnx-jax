# %%
import cv2
import jax.numpy as jnp
import numpy as np
import onnx

from onnx_jax.backend import run_model


def _cosin_sim(a, b):
    a = a.flatten()
    b = b.flatten()
    cos_sim = jnp.dot(a, b) / (jnp.linalg.norm(a) * jnp.linalg.norm(b))
    return cos_sim

# %%
# https://github.com/onnx/models/blob/master/vision/classification/mobilenet/model/mobilenetv2-7.onnx
fp = '/home/allen/ml_data/models/onnx/mobilenetv2-7.onnx'
onnx_model = onnx.load_model(fp)
graph = onnx_model.graph

# input_shape is [1,3,224,244]
input_shape = [x.dim_value for x in graph.input[0].type.tensor_type.shape.dim]
print(f"input shape: {input_shape}")

# https://commons.wikimedia.org/wiki/File:Giant_Panda_in_Beijing_Zoo_1.JPG
# imagenet id of panda is 388
fp_img = '/home/allen/ml_data/data/Giant_Panda_in_Beijing_Zoo_1.jpeg'
input_ = cv2.imread(fp_img, 1)
input_ = cv2.resize(input_, (224, 224))
input_ = jnp.expand_dims(input_, 0)
input_ = jnp.transpose(input_, [0, 3, 1, 2])
input_ = input_.astype(jnp.float32)
input_ = input_ / 255.0
input_ = input_ - jnp.array([0.485, 0.456, 0.406]).reshape([1, 3, 1, 1])
input_ = input_ / jnp.array([0.229, 0.224, 0.225]).reshape([1, 3, 1, 1])

# run model
outputs = run_model(onnx_model, [input_])
print(f"onnx-jax result: {jnp.argmax(outputs[0])}")

try:
    import onnxruntime as ort
    sess = ort.InferenceSession(fp)
    sess.get_inputs()
    out = sess.run(None, {graph.input[0].name: np.asarray(input_)})
    print(f"onnxruntime reult: {np.argmax(out[0])}")

    # compare with onnxruntime reult
    sim = _cosin_sim(jnp.asarray(out[0]), outputs[0])
    print(f"Output tensor similarity with onnxruntime: {sim}")
except:
    pass
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# input shape: [1, 3, 224, 224]
# running: Conv, mobilenetv20_features_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_batchnorm0_fwd
# running: Relu, mobilenetv20_features_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck0_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck0_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck0_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck0_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck0_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck0_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck0_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck0_batchnorm2_fwd
# running: Conv, mobilenetv20_features_linearbottleneck1_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck1_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck1_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck1_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck1_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck1_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck1_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck1_batchnorm2_fwd
# running: Conv, mobilenetv20_features_linearbottleneck2_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck2_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck2_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck2_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck2_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck2_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck2_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck2_batchnorm2_fwd
# running: Add, mobilenetv20_features_linearbottleneck2_elemwise_add0
# running: Conv, mobilenetv20_features_linearbottleneck3_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck3_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck3_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck3_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck3_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck3_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck3_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck3_batchnorm2_fwd
# running: Conv, mobilenetv20_features_linearbottleneck4_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck4_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck4_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck4_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck4_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck4_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck4_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck4_batchnorm2_fwd
# running: Add, mobilenetv20_features_linearbottleneck4_elemwise_add0
# running: Conv, mobilenetv20_features_linearbottleneck5_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck5_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck5_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck5_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck5_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck5_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck5_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck5_batchnorm2_fwd
# running: Add, mobilenetv20_features_linearbottleneck5_elemwise_add0
# running: Conv, mobilenetv20_features_linearbottleneck6_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck6_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck6_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck6_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck6_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck6_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck6_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck6_batchnorm2_fwd
# running: Conv, mobilenetv20_features_linearbottleneck7_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck7_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck7_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck7_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck7_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck7_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck7_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck7_batchnorm2_fwd
# running: Add, mobilenetv20_features_linearbottleneck7_elemwise_add0
# running: Conv, mobilenetv20_features_linearbottleneck8_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck8_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck8_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck8_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck8_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck8_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck8_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck8_batchnorm2_fwd
# running: Add, mobilenetv20_features_linearbottleneck8_elemwise_add0
# running: Conv, mobilenetv20_features_linearbottleneck9_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck9_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck9_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck9_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck9_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck9_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck9_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck9_batchnorm2_fwd
# running: Add, mobilenetv20_features_linearbottleneck9_elemwise_add0
# running: Conv, mobilenetv20_features_linearbottleneck10_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck10_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck10_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck10_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck10_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck10_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck10_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck10_batchnorm2_fwd
# running: Conv, mobilenetv20_features_linearbottleneck11_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck11_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck11_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck11_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck11_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck11_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck11_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck11_batchnorm2_fwd
# running: Add, mobilenetv20_features_linearbottleneck11_elemwise_add0
# running: Conv, mobilenetv20_features_linearbottleneck12_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck12_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck12_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck12_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck12_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck12_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck12_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck12_batchnorm2_fwd
# running: Add, mobilenetv20_features_linearbottleneck12_elemwise_add0
# running: Conv, mobilenetv20_features_linearbottleneck13_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck13_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck13_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck13_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck13_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck13_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck13_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck13_batchnorm2_fwd
# running: Conv, mobilenetv20_features_linearbottleneck14_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck14_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck14_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck14_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck14_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck14_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck14_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck14_batchnorm2_fwd
# running: Add, mobilenetv20_features_linearbottleneck14_elemwise_add0
# running: Conv, mobilenetv20_features_linearbottleneck15_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck15_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck15_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck15_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck15_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck15_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck15_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck15_batchnorm2_fwd
# running: Add, mobilenetv20_features_linearbottleneck15_elemwise_add0
# running: Conv, mobilenetv20_features_linearbottleneck16_conv0_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck16_batchnorm0_fwd
# running: Relu, mobilenetv20_features_linearbottleneck16_relu0_fwd
# running: Conv, mobilenetv20_features_linearbottleneck16_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck16_batchnorm1_fwd
# running: Relu, mobilenetv20_features_linearbottleneck16_relu1_fwd
# running: Conv, mobilenetv20_features_linearbottleneck16_conv2_fwd
# running: BatchNormalization, mobilenetv20_features_linearbottleneck16_batchnorm2_fwd
# running: Conv, mobilenetv20_features_conv1_fwd
# running: BatchNormalization, mobilenetv20_features_batchnorm1_fwd
# running: Relu, mobilenetv20_features_relu1_fwd
# running: GlobalAveragePool, mobilenetv20_features_pool0_fwd
# running: Conv, mobilenetv20_output_pred_fwd
# running: Reshape, mobilenetv20_output_flatten0_reshape0
# onnx-jax result: 388
# onnxruntime reult: 388
# Output tensor similarity with onnxruntime: 0.9999996423721313
